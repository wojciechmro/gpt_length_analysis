# %% [markdown]
# # Data Collection - Control Group

# %% [markdown]
# Control group is gathered to **establish a baseline of response length variability without the influence of length-defining keywords**.
# <br><br>
# It consists of 500 responses (5 sets of 100) from ChatGPT ("gpt-3.5-turbo" model) collected using `generate_responses.py`.
# <br><br>
# As the prompt, prompt templates from `prompt_templates.py` were used without specifying any keywords.
# <br><br>
# These responses serve as a reference point for comparing and measuring the effects of different keywords on response lengths.
# <br><br>
# Data from control group will **help to determine template-specific keywords by analyzing the response length distribution** in `2_EDA_Control_Group.ipynb`.

# %% [markdown]
# # Setup

# %%
# LIBRARIES
import pandas as pd
import os
from typing import Dict  # type hinting

# FILES
from generate_responses import (
    generate_responses,
)  # function to generate responses from OpenAI
import prompt_templates

# CONSTANTS
N_RESPONSES = 100  # set number of responses to generate per prompt
PROMPT_TITLE_TEMPLATE = (
    prompt_templates.prompt_title_template
)  # Dict[str, str] -> prompt titles (str) and templates (str) with placeholders for length defining keywords

# COLORS FOR PRINTING
GRAY = "\033[90m"
RED = "\033[91m"
GREEN = "\033[92m"
YELLOW = "\033[93m"
PURPLE = "\033[95m"
CYAN = "\033[96m"
RESET = "\033[0m"

# %% [markdown]
# # Response Collection: Control Group without specyfing length defining keywords

# %%
def control_group_collection(prompt_title_template: Dict[str, str]) -> None:
    for prompt_title, template in prompt_title_template.items():
        print(
            f"{YELLOW}GENERATING ALL RESPONSES FOR {CYAN}{prompt_title}{YELLOW} PROMPT TEMPLATE...{RESET}"
        )
        print(f"File being created: {GREEN}{prompt_title}_control.csv{RESET}")

        prompt = template.format("")  # no length defining keyword for control group
        prompt = " ".join(prompt.split())  # delete double space in prompt
        print(f"Prompt used: {GRAY}{prompt}{RESET}")

        generate_responses(
            n=N_RESPONSES,
            prompt=prompt,
            filename_prefix=prompt_title,
            filename_suffix="control",  # manually set filename suffix, because no length defining keyword was used
            folder_type="control",  # default is "experimental"
        )

# %%
control_group_collection(PROMPT_TITLE_TEMPLATE)
# Out:
# GENERATING ALL RESPONSES FOR email PROMPT TEMPLATE...
# File being created: email_control.csv
# Prompt used: Write a business email that is professional, clear, and concise. The email should be addressed to a potential business client. Please introduce my paper company and our offer. Invite the recipient to a meeting in my office at 2PM on Wednesday.
# Responses gathered: 1  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 2  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 3  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 4  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 5  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 6  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 7  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 8  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 9  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 10  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 11  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 12  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 13  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 14  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 15  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 16  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 17  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 18  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 19  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 20  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 21  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 22  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 23  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 24  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 25  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 26  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 27  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 28  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 29  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 30  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 31  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 32  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 33  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 34  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 35  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 36  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 37  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 38  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 39  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 40  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 41  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 42  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 43  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 44  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 45  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 46  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 47  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 48  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 49  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 50  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 51  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 52  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 53  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 54  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 55  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 56  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 57  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 58  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 59  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 60  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 61  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 62  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 63  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 64  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 65  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 66  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 67  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 68  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 69  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 70  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 71  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 72  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 73  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 74  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 75  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 76  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 77  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 78  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 79  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 80  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 81  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 82  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 83  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 84  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 85  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 86  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 87  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 88  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 89  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 90  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 91  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 92  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 93  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 94  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 95  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 96  |  Working on: email_control.csv  |  Errors occured: 0
# Responses gathered: 97  |  Working on: email_control.csv  |  Errors occured: 0
# Error generating response 97: Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=600)
# Responses gathered: 97  |  Working on: email_control.csv  |  Errors occured: 1
# Responses gathered: 98  |  Working on: email_control.csv  |  Errors occured: 1
# Responses gathered: 99  |  Working on: email_control.csv  |  Errors occured: 1
# Responses gathered: 100  |  Working on: email_control.csv  |  Errors occured: 1
# Filename email_control.csv was created!
#
# GENERATING ALL RESPONSES FOR social PROMPT TEMPLATE...
# File being created: social_control.csv
# Prompt used: Write a social media post about a new announcement from OpenAI. Give an opinion about this announcement and ask followers about their opinion on this subject. Write a CTA.
# Responses gathered: 1  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 2  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 3  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 4  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 5  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 6  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 7  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 8  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 9  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 10  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 11  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 12  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 13  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 14  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 15  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 16  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 17  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 18  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 19  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 20  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 21  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 22  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 23  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 24  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 25  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 26  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 27  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 28  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 29  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 30  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 31  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 32  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 33  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 34  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 35  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 36  |  Working on: social_control.csv  |  Errors occured: 0
# Responses gathered: 37  |  Working on: social_control.csv  |  Errors occured: 0
# Error generating response 37: The server is overloaded or not ready yet.
# Responses gathered: 37  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 38  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 39  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 40  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 41  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 42  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 43  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 44  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 45  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 46  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 47  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 48  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 49  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 50  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 51  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 52  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 53  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 54  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 55  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 56  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 57  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 58  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 59  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 60  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 61  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 62  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 63  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 64  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 65  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 66  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 67  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 68  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 69  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 70  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 71  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 72  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 73  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 74  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 75  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 76  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 77  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 78  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 79  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 80  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 81  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 82  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 83  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 84  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 85  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 86  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 87  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 88  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 89  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 90  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 91  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 92  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 93  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 94  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 95  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 96  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 97  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 98  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 99  |  Working on: social_control.csv  |  Errors occured: 1
# Responses gathered: 100  |  Working on: social_control.csv  |  Errors occured: 1
# Filename social_control.csv was created!
#
# GENERATING ALL RESPONSES FOR cover PROMPT TEMPLATE...
# File being created: cover_control.csv
# Prompt used: Write a cover letter to the hiring manager. I'm applying for a job in Data Science. I'm very motivated and eager to learn. I love AI and sports are my passion. Make a good impression.
# Responses gathered: 1  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 2  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 3  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 4  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 5  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 6  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 7  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 8  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 9  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 10  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 11  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 12  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 13  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 14  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 15  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 16  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 17  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 18  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 19  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 20  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 21  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 22  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 23  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 24  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 25  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 26  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 27  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 28  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 29  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 30  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 31  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 32  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 33  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 34  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 35  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 36  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 37  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 38  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 39  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 40  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 41  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 42  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 43  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 44  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 45  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 46  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 47  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 48  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 49  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 50  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 51  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 52  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 53  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 54  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 55  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 56  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 57  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 58  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 59  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 60  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 61  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 62  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 63  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 64  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 65  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 66  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 67  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 68  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 69  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 70  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 71  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 72  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 73  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 74  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 75  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 76  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 77  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 78  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 79  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 80  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 81  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 82  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 83  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 84  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 85  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 86  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 87  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 88  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 89  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 90  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 91  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 92  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 93  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 94  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 95  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 96  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 97  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 98  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 99  |  Working on: cover_control.csv  |  Errors occured: 0
# Responses gathered: 100  |  Working on: cover_control.csv  |  Errors occured: 0
# Filename cover_control.csv was created!
#
# GENERATING ALL RESPONSES FOR essay PROMPT TEMPLATE...
# File being created: essay_control.csv
# Prompt used: Write a essay about prompt engineering. Explain how it will be one of the most crucial skill to learn in 2023. Emphasize its importance and give forecast for the future.
# Responses gathered: 1  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 2  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 3  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 4  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 5  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 6  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 7  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 8  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 9  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 10  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 11  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 12  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 13  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 14  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 15  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 16  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 17  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 18  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 19  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 20  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 21  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 22  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 23  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 24  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 25  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 26  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 27  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 28  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 29  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 30  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 31  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 32  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 33  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 34  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 35  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 36  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 37  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 38  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 39  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 40  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 41  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 42  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 43  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 44  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 45  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 46  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 47  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 48  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 49  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 50  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 51  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 52  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 53  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 54  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 55  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 56  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 57  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 58  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 59  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 60  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 61  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 62  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 63  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 64  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 65  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 66  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 67  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 68  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 69  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 70  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 71  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 72  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 73  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 74  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 75  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 76  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 77  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 78  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 79  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 80  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 81  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 82  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 83  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 84  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 85  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 86  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 87  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 88  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 89  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 90  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 91  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 92  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 93  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 94  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 95  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 96  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 97  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 98  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 99  |  Working on: essay_control.csv  |  Errors occured: 0
# Responses gathered: 100  |  Working on: essay_control.csv  |  Errors occured: 0
# Filename essay_control.csv was created!
#
# GENERATING ALL RESPONSES FOR explanation PROMPT TEMPLATE...
# File being created: explanation_control.csv
# Prompt used: Give a explanation of what polymorphism is with examples of its usage.
# Responses gathered: 1  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 2  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 3  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 4  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 5  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 6  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 7  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 8  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 9  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 10  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 11  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 12  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 13  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 14  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 15  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 16  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 17  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 18  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 19  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 20  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 21  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 22  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 23  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 24  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 25  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 26  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 27  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 28  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 29  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 30  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 31  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 32  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 33  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 34  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 35  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 36  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 37  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 38  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 39  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 40  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 41  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 42  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 43  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 44  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 45  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 46  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 47  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 48  |  Working on: explanation_control.csv  |  Errors occured: 0
# Responses gathered: 49  |  Working on: explanation_control.csv  |  Errors occured: 0
# Error generating response 49: Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=600)
# Responses gathered: 49  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 50  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 51  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 52  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 53  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 54  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 55  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 56  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 57  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 58  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 59  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 60  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 61  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 62  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 63  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 64  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 65  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 66  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 67  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 68  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 69  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 70  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 71  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 72  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 73  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 74  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 75  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 76  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 77  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 78  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 79  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 80  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 81  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 82  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 83  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 84  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 85  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 86  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 87  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 88  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 89  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 90  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 91  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 92  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 93  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 94  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 95  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 96  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 97  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 98  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 99  |  Working on: explanation_control.csv  |  Errors occured: 1
# Responses gathered: 100  |  Working on: explanation_control.csv  |  Errors occured: 1
# Filename explanation_control.csv was created!

# %% [markdown]
# # Assert shape of all CSV's

# %% [markdown]
# If runs without output, all CSV's have the same shape.

# %%
desired_number_of_responses = N_RESPONSES
desired_number_of_columns = 4
folder_type = "control"

directory = os.getcwd() + f"/data/raw_{folder_type}_group"

for filename in os.listdir(directory):
    file_path = os.path.join(directory, filename)

    if filename.endswith(".csv"):
        df = pd.read_csv(file_path)
        # making sure that all files have same shape
        assert df.shape == (
            desired_number_of_responses,
            desired_number_of_columns,
        ), f"{filename} has shape {df.shape} instead of ({desired_number_of_responses}, {desired_number_of_columns})"

# %% [markdown]
# # Checking if all files were collected

# %%
csv_count = 0

for file in os.listdir(directory):
    if file.endswith(".csv"):
        csv_count += 1

# Print the number of CSV files
print("Number of CSV files:", csv_count)
# Out:
# Number of CSV files: 5
